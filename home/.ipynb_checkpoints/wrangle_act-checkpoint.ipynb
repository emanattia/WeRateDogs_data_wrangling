# %%
#import libraries
import pandas as pd
import numpy as np
import os
import requests
#import tweepy
import json
#import time
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Gathering Data

# %%
#load twitter_archive data
twitter_archive = pd.read_csv('twitter-archive-enhanced-2.csv')

# %%
#make sure that the data loded successfully
twitter_archive.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
#get image-predictions-3.tsv data

URL ='https://video.udacity-data.com/topher/2018/November/5bf60c69_image-predictions-3/image-predictions-3.tsv'
response= requests.get(URL)
with open('image-predictions-3.tsv', mode ='wb') as file:
    file.write(response.content)

# %%
image_predictions = pd.read_csv('image-predictions-3.tsv', sep='\t')

# %%
image_predictions.head(10)
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5  666050758794694657  https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6  666051853826850816  https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7  666055525042405380  https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8  666057090499244032  https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9  666058600524156928  https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# ...

# %%
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer

# Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# These are hidden to comply with Twitter's API terms and conditions
consumer_key = 'HIDDEN'
consumer_secret = 'HIDDEN'
access_token = 'HIDDEN'
access_secret = 'HIDDEN'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# NOTE TO STUDENT WITH MOBILE VERIFICATION ISSUES:
# df_1 is a DataFrame with the twitter_archive_enhanced.csv file. You may have to
# change line 17 to match the name of your DataFrame with twitter_archive_enhanced.csv
# NOTE TO REVIEWER: this student had mobile verification issues so the following
# Twitter API code was sent to this student from a Udacity instructor
# Tweet IDs for which to gather additional data via Twitter's API
tweet_ids = twitter_archive.tweet_id.values
len(tweet_ids)

# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
count = 0
fails_dict = {}
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as outfile:
    # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)

# %%
#open json file and append tweets in tweetsList
tweetsList=[]
with open('tweet-json copy', encoding='utf-8') as file:  
    for x in file:
        tweetsList.append(json.loads(x))

# %%
tweetsList[0]
# Out:
# {'created_at': 'Tue Aug 01 16:23:56 +0000 2017',
#  'id': 892420643555336193,
#  'id_str': '892420643555336193',
#  'full_text': "This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU",
#  'truncated': False,
#  'display_text_range': [0, 85],
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [],
#   'media': [{'id': 892420639486877696,
#     'id_str': '892420639486877696',
#     'indices': [86, 109],
#     'media_url': 'http://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg',
#     'url': 'https://t.co/MgUWQ76dJU',
#     'display_url': 'pic.twitter.com/MgUWQ76dJU',
#     'expanded_url': 'https://twitter.com/dog_rates/status/892420643555336193/photo/1',
#     'type': 'photo',
#     'sizes': {'large': {'w': 540, 'h': 528, 'resize': 'fit'},
#      'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
# ...

# %%
#create data frame for json tweets
tweets_df = pd.DataFrame(tweetsList, columns = ['id', 'favorite_count','retweet_count'])

# %%
#show first 5 rows of data
tweets_df.head()
# Out:
#                    id  favorite_count  retweet_count
# 0  892420643555336193           39467           8853
# 1  892177421306343426           33819           6514
# 2  891815181378084864           25461           4328
# 3  891689557279858688           42908           8964
# 4  891327558926688256           41048           9774

# %%
#save data
tweets_df.to_csv('tweet_json.txt', encoding = 'utf-8', index=False)

# %% [markdown]
# # Assessing Data

# %% [markdown]
# ### Assessing twitter_archive

# %%
#show twitter_archive data frame
twitter_archive
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %%
#show first 10 rows of the data frame
twitter_archive.head(10)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
# 5  891087950875897856                    NaN                  NaN
# 6  890971913173991426                    NaN                  NaN
# 7  890729181411237888                    NaN                  NaN
# 8  890609185150312448                    NaN                  NaN
# 9  890240255349198849                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
# 5  2017-07-29 00:08:17 +0000
# ...

# %%
#get the last 10 rows in the data frame
twitter_archive.tail(10)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2346  666058600524156928                    NaN                  NaN
# 2347  666057090499244032                    NaN                  NaN
# 2348  666055525042405380                    NaN                  NaN
# 2349  666051853826850816                    NaN                  NaN
# 2350  666050758794694657                    NaN                  NaN
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 2346  2015-11-16 01:01:59 +0000
# 2347  2015-11-16 00:55:59 +0000
# 2348  2015-11-16 00:49:46 +0000
# 2349  2015-11-16 00:35:11 +0000
# 2350  2015-11-16 00:30:50 +0000
# ...

# %% [markdown]
# #### Tidiness:
# "There's 4 columns (doggo, floofer, pupper, puppo)that dog stage separated into them"
# #### Quality
# "The format of the source is bad"

# %%
#get info about twitter_archive
twitter_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %% [markdown]
# #### Quality:
# "(timestamp, retweeted_status_timestamp) should be datetime not object"

# %%
#How many duplicated tweet_id
twitter_archive['tweet_id'].duplicated().sum()
# Out:
# 0

# %%
#statistics describtion of twitter_archive
twitter_archive.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
#count of each rating_numerator
twitter_archive.rating_numerator.value_counts()
# Out:
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 1         9
# 2         9
# 420       2
# 0         2
# 15        2
# 75        2
# 80        1
# 20        1
# 24        1
# 26        1
# 44        1
# 50        1
# 60        1
# 165       1
# 84        1
# 88        1
# 144       1
# 182       1
# 143       1
# 666       1
# 960       1
# 1776      1
# 17        1
# 27        1
# 45        1
# 99        1
# 121       1
# 204       1
# Name: rating_numerator, dtype: int64

# %%
#get text that take 0 in rating numerator
twitter_archive.loc[twitter_archive.rating_numerator==0,'text']
# Out:
# 315     When you're so blinded by your systematic plag...
# 1016    PUPDATE: can't see any. Even if I could, I cou...
# Name: text, dtype: object

# %%
#count of numerator rating less than 10
twitter_archive[twitter_archive['rating_numerator']<10].count()[0]
# Out:
# 440

# %%
#count of each rating denominator
twitter_archive.rating_denominator.value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
#How many rating_denominator not equal 10
twitter_archive[twitter_archive['rating_denominator']!=10].count()[0]
# Out:
# 23

# %% [markdown]
# #### Quality:
# "The numerator and denominator have invalid values"

# %%
#count of each name
twitter_archive.name.value_counts()
# Out:
# None         745
# a             55
# Charlie       12
# Oliver        11
# Lucy          11
# Cooper        11
# Penny         10
# Tucker        10
# Lola          10
# Winston        9
# Bo             9
# the            8
# Sadie          8
# an             7
# Toby           7
# Bailey         7
# Daisy          7
# Buddy          7
# Scout          6
# Jack           6
# Jax            6
# Leo            6
# Dave           6
# Milo           6
# Oscar          6
# Stanley        6
# Bella          6
# Koda           6
# Rusty          6
# Sunny          5
#             ...
# Jennifur       1
# Bayley         1
# Brady          1
# Emanuel        1
# Bookstore      1
# Heinrich       1
# Nigel          1
# Alexander      1
# Miguel         1
# Gordon         1
# Shelby         1
# Batdog         1
# Fabio          1
# Rueben         1
# Gert           1
# Butters        1
# Jim            1
# Bilbo          1
# Obie           1
# Ester          1
# Lacy           1
# ...

# %% [markdown]
# #### Quality:
# "There are invalid (a, an ,the) and missing names"

# %%
twitter_archive[twitter_archive['retweeted_status_id'].notnull()].count()
# Out:
# tweet_id                      181
# in_reply_to_status_id           0
# in_reply_to_user_id             0
# timestamp                     181
# source                        181
# text                          181
# retweeted_status_id           181
# retweeted_status_user_id      181
# retweeted_status_timestamp    181
# expanded_urls                 180
# rating_numerator              181
# rating_denominator            181
# name                          181
# doggo                         181
# floofer                       181
# pupper                        181
# puppo                         181
# dtype: int64

# %% [markdown]
# #### Quality
# "There are 181 retweets and should be removed"

# %% [markdown]
# ### Assessing image_predictions

# %%
#show the image_predictions data frame
image_predictions
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7     666055525042405380    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# ...

# %%
#get info about image_predictions
image_predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %% [markdown]
# #### Quality:
#
# "Missing values from images dataset because there's 2075 rows instead of 2356."
# <br />
# "some p1 ,p2 and p3 names start with uppercase characters and other with lowercase and have _ instead of spaces"

# %%
#describe image_predictions statistics
image_predictions.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %%
#How many dublicated tweet_id
image_predictions['tweet_id'].duplicated().sum()
# Out:
# 0

# %%
#How many dublicated Images
image_predictions['jpg_url'].duplicated().sum()
# Out:
# 66

# %%
#count of each img_num
image_predictions.img_num.value_counts()
# Out:
# 1    1780
# 2     198
# 3      66
# 4      31
# Name: img_num, dtype: int64

# %% [markdown]
# ### Assessing tweets_df

# %%
#show tweet df
tweets_df
# Out:
#                       id  favorite_count  retweet_count
# 0     892420643555336193           39467           8853
# 1     892177421306343426           33819           6514
# 2     891815181378084864           25461           4328
# 3     891689557279858688           42908           8964
# 4     891327558926688256           41048           9774
# 5     891087950875897856           20562           3261
# 6     890971913173991426           12041           2158
# 7     890729181411237888           56848          16716
# 8     890609185150312448           28226           4429
# 9     890240255349198849           32467           7711
# 10    890006608113172480           31166           7624
# 11    889880896479866881           28268           5156
# 12    889665388333682689           38818           8538
# 13    889638837579907072           27672           4735
# 14    889531135344209921           15359           2321
# 15    889278841981685760           25652           5637
# ...

# %% [markdown]
# #### Quality:
#
# "Missing data because there's 2354 rows instead of 2356."

# %%
#info about tweets_df
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# id                2354 non-null int64
# favorite_count    2354 non-null int64
# retweet_count     2354 non-null int64
# dtypes: int64(3)
# memory usage: 55.2 KB

# %%
#statistics describtion of tweets_df
tweets_df.describe()
# Out:
#                  id  favorite_count  retweet_count
# count  2.354000e+03     2354.000000    2354.000000
# mean   7.426978e+17     8080.968564    3164.797366
# std    6.852812e+16    11814.771334    5284.770364
# min    6.660209e+17        0.000000       0.000000
# 25%    6.783975e+17     1415.000000     624.500000
# 50%    7.194596e+17     3603.500000    1473.500000
# 75%    7.993058e+17    10122.250000    3652.000000
# max    8.924206e+17   132810.000000   79515.000000

# %%
#How many duplicated tweet_id
tweets_df['id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Tidiness
# 1- There's 4 columns (doggo, floofer, pupper, puppo)that dog stage separated into them <br>
# 2- Merge tweets_df and image_predictions into twitter_archive. <br>

# %% [markdown]
# ## Quality
# 1- The format of the source is bad in twitter_archive. <br>
# 2- There are 181 retweets and should be removed in twitter_archive.<br>
# 3- The numerator and denominator have invalid values in twitter_archive.<br>
# 4- The null objects in the columns are non-null but take (None to NaN).<br>
# 5- There are invalid (a, an ,the) and missing names in twitter_archive.<br>
# 6- (timestamp, retweeted_status_timestamp) should be datetime not object in twitter_archive.<br>
# 7- separate the timestamp into day,year and month <br>
# 8- There's rows with no images in in image_predictions. <br>
# 9- some p1 ,p2 and p3 names start with uppercase characters and other with lowercase and have _ instead of spaces in image_predictions.<br>
# 10- Missing values from images dataset because there's 2075 rows instead of 2356 in image_predictions.<br>
# 11- There's missing data because there's 2354 rows instead of 2356 in tweets_df.<br>

# %% [markdown]
# # Cleaning

# %%
#copy data
twitter_archive_clean = twitter_archive.copy()
image_predictions_clean = image_predictions.copy()
tweets_df_clean = tweets_df.copy()

# %% [markdown]
# #### Define
# "Rename the id in tweets_df_clean to be same as other files"

# %% [markdown]
# #### Code

# %%
#rename the id to be same as other files
tweets_df_clean=tweets_df_clean.rename(columns ={'id':'tweet_id'})

# %% [markdown]
# #### Test

# %%
tweets_df_clean.head()
# Out:
#              tweet_id  favorite_count  retweet_count
# 0  892420643555336193           39467           8853
# 1  892177421306343426           33819           6514
# 2  891815181378084864           25461           4328
# 3  891689557279858688           42908           8964
# 4  891327558926688256           41048           9774

# %% [markdown]
# #### Define
#
# **Quality issue 2:** There are 181 retweets and should be removed in twitter_archive.
# - drop retweeted_status_user_id rows

# %% [markdown]
# #### Code

# %%
twitter_archive_clean=twitter_archive[twitter_archive['retweeted_status_id'].isnull()]

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.retweeted_status_id.notna().sum()
# Out:
# 0

# %% [markdown]
# #### Define
# **Quality issue 1:** (The format of the source is bad in twitter_archive. ) this column will be deleted with the columns that i won't use in the analysis. <br>
# - "drop useless columns in analysis from twitter archive" <br>

# %% [markdown]
# #### Code

# %%
#drop useless columns in twitter archive
twitter_archive_clean.drop(['in_reply_to_status_id',
                            'in_reply_to_user_id',
                            'retweeted_status_id',
                            'retweeted_status_user_id',
                            'retweeted_status_timestamp',
                            'expanded_urls',
                            'source'],axis=1 ,inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.head(2)
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
#
#                                                 text  rating_numerator  \
# 0  This is Phineas. He's a mystical boy. Only eve...                13
# 1  This is Tilly. She's just checking pup on you....                13
#
#    rating_denominator     name doggo floofer pupper puppo
# 0                  10  Phineas  None    None   None  None
# 1                  10    Tilly  None    None   None  None

# %%
twitter_archive_clean.groupby(['doggo', 'floofer', 'pupper', 'puppo']).size().reset_index().rename(columns={0: "count"})
# Out:
#    doggo  floofer  pupper  puppo  count
# 0   None     None    None   None   1831
# 1   None     None    None  puppo     24
# 2   None     None  pupper   None    224
# 3   None  floofer    None   None      9
# 4  doggo     None    None   None     75
# 5  doggo     None    None  puppo      1
# 6  doggo     None  pupper   None     10
# 7  doggo  floofer    None   None      1

# %% [markdown]
# #### Define <br>
# **Tidiness issue 1:** There's 4 columns (doggo, floofer, pupper, puppo)that dog stage separated into them. <br>
#
# - "Melt the doggo, floofer, pupper and puppo columns to dogs and dogs_stage column."
# - "drop dogs."

# %% [markdown]
# #### Code

# %%
twitter_archive_clean = pd.melt(twitter_archive_clean, id_vars=['tweet_id',                                          
                                                                'timestamp',
                                                                'text',
                                                                'rating_numerator',
                                                                'rating_denominator',
                                                                'name'],
                               var_name='dogs', value_name='dogs_stage')

# %%
#drop dogs column in twitter archive
twitter_archive_clean.drop(['dogs'],axis=1 ,inplace=True)

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8700 entries, 0 to 8699
# Data columns (total 7 columns):
# tweet_id              8700 non-null int64
# timestamp             8700 non-null object
# text                  8700 non-null object
# rating_numerator      8700 non-null int64
# rating_denominator    8700 non-null int64
# name                  8700 non-null object
# dogs_stage            8700 non-null object
# dtypes: int64(3), object(4)
# memory usage: 475.9+ KB

# %%
twitter_archive_clean.sample(20)
# Out:
#                 tweet_id                  timestamp  \
# 1826  672272411274932228  2015-12-03 04:33:27 +0000
# 5244  739979191639244800  2016-06-07 00:36:02 +0000
# 749   756303284449767430  2016-07-22 01:42:09 +0000
# 4476  864197398364647424  2017-05-15 19:14:50 +0000
# 4503  857746408056729600  2017-04-28 00:00:54 +0000
# 2588  813127251579564032  2016-12-25 21:00:18 +0000
# 5126  751950017322246144  2016-07-10 01:23:49 +0000
# 7714  702539513671897089  2016-02-24 17:04:07 +0000
# 3771  678021115718029313  2015-12-19 01:16:45 +0000
# 903   738885046782832640  2016-06-04 00:08:17 +0000
# 6299  670303360680108032  2015-11-27 18:09:09 +0000
# 5184  747512671126323200  2016-06-27 19:31:23 +0000
# 6798  834086379323871233  2017-02-21 17:04:24 +0000
# 3266  709449600415961088  2016-03-14 18:42:20 +0000
# 1340  690735892932222976  2016-01-23 03:20:44 +0000
# 3795  677187300187611136  2015-12-16 18:03:28 +0000
# 1838  672160042234327040  2015-12-02 21:06:56 +0000
# ...

# %%
twitter_archive_clean['dogs_stage'].value_counts()
# Out:
# None       8344
# pupper      234
# doggo        87
# puppo        25
# floofer      10
# Name: dogs_stage, dtype: int64

# %% [markdown]
# #### Define <br>
# "Sort dogs_stage and delete duplicted based on tweet_id"

# %% [markdown]
# #### Code

# %%
twitter_archive_clean = twitter_archive_clean.sort_values('dogs_stage').drop_duplicates(subset='tweet_id',
                                                                                        keep='last')

# %% [markdown]
# #### Test

# %%
twitter_archive_clean['dogs_stage'].value_counts()
# Out:
# None       1831
# pupper      234
# doggo        75
# puppo        25
# floofer      10
# Name: dogs_stage, dtype: int64

# %% [markdown]
# #### Define <Br>
# **Quality issue 3:** The numerator and denominator have invalid values in twitter_archive.
# - "correct the denominator"

# %%
twitter_archive_clean['rating_denominator']=10

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.rating_denominator.value_counts()
# Out:
# 10    2175
# Name: rating_denominator, dtype: int64

# %%
twitter_archive_clean.rating_numerator.value_counts()
# Out:
# 12      500
# 10      442
# 11      426
# 13      307
# 9       156
# 8        98
# 7        54
# 14       43
# 5        36
# 6        32
# 3        19
# 4        17
# 2         9
# 1         8
# 420       2
# 0         2
# 20        1
# 24        1
# 26        1
# 84        1
# 44        1
# 50        1
# 60        1
# 80        1
# 165       1
# 88        1
# 144       1
# 182       1
# 143       1
# 666       1
# 960       1
# 1776      1
# 15        1
# 17        1
# 27        1
# 45        1
# 75        1
# 99        1
# 121       1
# 204       1
# Name: rating_numerator, dtype: int64

# %%
#merged_data['dogs_stage'=="None"]=np.nan

# %% [markdown]
# #### Define
# - correct the numerator

# %% [markdown]
# #### Code

# %%
#extract numerators from text
ratings = twitter_archive_clean.text.str.extract('((?:\d+\.)?\d+)\/(\d+)', expand=True)

# %%
#convert ratings data type
ratings = ratings.astype(float)

# %%
#replace rating_numerator with the extracted numerators from the text
twitter_archive_clean.rating_numerator = ratings

# %%
#convert ratings data type
twitter_archive_clean['rating_numerator'] = twitter_archive_clean['rating_numerator'].astype(float)

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 2095 to 7298
# Data columns (total 7 columns):
# tweet_id              2175 non-null int64
# timestamp             2175 non-null object
# text                  2175 non-null object
# rating_numerator      2175 non-null float64
# rating_denominator    2175 non-null int64
# name                  2175 non-null object
# dogs_stage            2175 non-null object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 135.9+ KB

# %%
twitter_archive_clean.head()
# Out:
#                 tweet_id                  timestamp  \
# 2095  667443425659232256  2015-11-19 20:44:47 +0000
# 2094  667453023279554560  2015-11-19 21:22:56 +0000
# 2093  667455448082227200  2015-11-19 21:32:34 +0000
# 2092  667470559035432960  2015-11-19 22:32:36 +0000
# 2091  667491009379606528  2015-11-19 23:53:52 +0000
#
#                                                    text  rating_numerator  \
# 2095  Exotic dog here. Long neck. Weird paws. Obsess...               6.0
# 2094  Meet Cupcake. I would do unspeakable things fo...              11.0
# 2093  This is Reese and Twips. Reese protects Twips....               7.0
# 2092  This is a northern Wahoo named Kohl. He runs t...              11.0
# 2091  Two dogs in this one. Both are rare Jujitsu Py...               7.0
#
#       rating_denominator     name dogs_stage
# 2095                  10     None       None
# 2094                  10  Cupcake       None
# 2093                  10    Reese       None
# ...

# %% [markdown]
# #### Define <br>
# **Quality issue 4 :**The null objects in the columns are non-null but take (None to NaN).
# - "replace all dogs_stage that takes None to be null values"

# %% [markdown]
# #### Code

# %%
#replace all dogs_stage that takes None to nan
twitter_archive_clean.dogs_stage = twitter_archive_clean.dogs_stage.replace(regex=[ 'None'],value=np.nan)

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 2095 to 7298
# Data columns (total 7 columns):
# tweet_id              2175 non-null int64
# timestamp             2175 non-null object
# text                  2175 non-null object
# rating_numerator      2175 non-null float64
# rating_denominator    2175 non-null int64
# name                  2175 non-null object
# dogs_stage            344 non-null object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 135.9+ KB

# %%
twitter_archive_clean['dogs_stage'].value_counts()
# Out:
# pupper     234
# doggo       75
# puppo       25
# floofer     10
# Name: dogs_stage, dtype: int64

# %% [markdown]
# #### Define <br>
# **Quality issue 5 :**There are invalid (a, an ,the) and missing names in twitter_archive.
# - "get rid of invalid dog names (a, an, None)"

# %% [markdown]
# #### Code

# %%
#replace all names that's not characters or takes None to nan
twitter_archive_clean.name = twitter_archive_clean.name.replace(regex=['^[a-z]+', 'None'],value=np.nan)

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 2095 to 7298
# Data columns (total 7 columns):
# tweet_id              2175 non-null int64
# timestamp             2175 non-null object
# text                  2175 non-null object
# rating_numerator      2175 non-null float64
# rating_denominator    2175 non-null int64
# name                  1391 non-null object
# dogs_stage            344 non-null object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 135.9+ KB

# %%
#get the count of each dog name
twitter_archive_clean['name'].value_counts()
# Out:
# Charlie       11
# Lucy          11
# Oliver        10
# Cooper        10
# Tucker         9
# Penny          9
# Lola           8
# Sadie          8
# Winston        8
# Toby           7
# Daisy          7
# Bella          6
# Stanley        6
# Bo             6
# Jax            6
# Bailey         6
# Koda           6
# Oscar          6
# Buddy          5
# Bentley        5
# Milo           5
# Dave           5
# Louis          5
# Scout          5
# Chester        5
# Leo            5
# Rusty          5
# Maggie         4
# Sammy          4
# Dexter         4
#               ..
# Sojourner      1
# Rolf           1
# Jaycob         1
# Ester          1
# Nigel          1
# Shelby         1
# Gordon         1
# Davey          1
# Grizzie        1
# Herschel       1
# Bonaparte      1
# Nimbus         1
# Timber         1
# Tango          1
# Howie          1
# Noosh          1
# Winifred       1
# Dex            1
# Arlo           1
# Dixie          1
# Sweet          1
# ...

# %%
#number of null names in the data
twitter_archive_clean.name.isnull().sum()
# Out:
# 784

# %% [markdown]
# #### Define <br>
# **Quality issue 6 & 7:** (timestamp, retweeted_status_timestamp) should be datetime not object in twitter_archive.
# - "convert timestamp data type to date time and separeate it to day, month and year."

# %% [markdown]
# #### Code

# %%
#convert timestamp data type to date time
twitter_archive_clean['timestamp'] = pd.to_datetime(twitter_archive_clean['timestamp'])

# %%
#extract year, month and day to new columns
twitter_archive_clean['year'] = twitter_archive_clean['timestamp'].dt.year
twitter_archive_clean['month'] = twitter_archive_clean['timestamp'].dt.month
twitter_archive_clean['day'] = twitter_archive_clean['timestamp'].dt.day

# %%
#drop timestamp col
twitter_archive_clean.drop(['timestamp'], axis=1,inplace=True)

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 2095 to 7298
# Data columns (total 9 columns):
# tweet_id              2175 non-null int64
# text                  2175 non-null object
# rating_numerator      2175 non-null float64
# rating_denominator    2175 non-null int64
# name                  1391 non-null object
# dogs_stage            344 non-null object
# year                  2175 non-null int64
# month                 2175 non-null int64
# day                   2175 non-null int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 169.9+ KB

# %% [markdown]
# #### Define <br>
#
# **Quality issue 8:** There's rows with no images in image_predictions.
# - "delete rows with no images"

# %% [markdown]
# #### Code

# %%
#delete rows with no images
image_predictions_clean=image_predictions_clean[image_predictions_clean.jpg_url.notnull()]

# %% [markdown]
# #### Test

# %%
image_predictions_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 168.2+ KB

# %% [markdown]
# #### Define <br>
# **Quality issue 9:** some p1 ,p2 and p3 names start with uppercase characters and other with lowercase and have _ instead of spaces in image_predictions.
#
# - "capitalize the first character in p1 , p2 and p3 and replace _ with space"

# %% [markdown]
# #### Code

# %%
#capitalize the first carachter in p1 , p2 and p3 
image_predictions_clean['p1'] = image_predictions_clean['p1'].str.capitalize()
image_predictions_clean['p2'] = image_predictions_clean['p2'].str.capitalize()
image_predictions_clean['p3'] = image_predictions_clean['p3'].str.capitalize()

# %%
#replce _ with space in p1 , p2 and p3
image_predictions_clean['p1'] = image_predictions_clean['p1'].str.replace('_',' ')
image_predictions_clean['p2'] = image_predictions_clean['p2'].str.replace('_',' ')
image_predictions_clean['p3'] = image_predictions_clean['p3'].str.replace('_',' ')

# %% [markdown]
# #### Test

# %%
image_predictions_clean['p1']
# Out:
# 0            Welsh springer spaniel
# 1                           Redbone
# 2                   German shepherd
# 3               Rhodesian ridgeback
# 4                Miniature pinscher
# 5              Bernese mountain dog
# 6                        Box turtle
# 7                              Chow
# 8                     Shopping cart
# 9                  Miniature poodle
# 10                 Golden retriever
# 11                    Gordon setter
# 12                     Walker hound
# 13                              Pug
# 14                       Bloodhound
# 15                            Lhasa
# 16                   English setter
# 17                              Hen
# 18                 Desktop computer
# 19                Italian greyhound
# 20                      Maltese dog
# 21                 Three-toed sloth
# 22                               Ox
# 23                 Golden retriever
# 24                         Malamute
# 25                       Guinea pig
# ...

# %%
image_predictions_clean['p2']
# Out:
# 0                         Collie
# 1             Miniature pinscher
# 2                       Malinois
# 3                        Redbone
# 4                     Rottweiler
# 5               English springer
# 6                     Mud turtle
# 7                Tibetan mastiff
# 8                Shopping basket
# 9                       Komondor
# 10               Tibetan mastiff
# 11             Yorkshire terrier
# 12              English foxhound
# 13                  Bull mastiff
# 14               German shepherd
# 15                      Shih-tzu
# 16                  Newfoundland
# 17                          Cock
# 18                          Desk
# 19                   Toy terrier
# 20                    Toy poodle
# 21                         Otter
# 22                  Newfoundland
# 23      Chesapeake bay retriever
# 24                Siberian husky
# 25                         Skunk
# 26                  Afghan hound
# 27                   Toy terrier
# ...

# %%
image_predictions_clean['p3']
# Out:
# 0                 Shetland sheepdog
# 1               Rhodesian ridgeback
# 2                        Bloodhound
# 3                Miniature pinscher
# 4                          Doberman
# 5        Greater swiss mountain dog
# 6                          Terrapin
# 7                          Fur coat
# 8                  Golden retriever
# 9       Soft-coated wheaten terrier
# 10               Labrador retriever
# 11                         Pekinese
# 12                     Ibizan hound
# 13                   French bulldog
# 14                         Malinois
# 15                   Dandie dinmont
# 16                           Borzoi
# 17                        Partridge
# 18                         Bookcase
# 19                          Basenji
# 20                 Miniature poodle
# 21                   Great grey owl
# 22                      Groenendael
# 23               Labrador retriever
# 24                       Eskimo dog
# 25                          Hamster
# ...

# %% [markdown]
# #### Define <br>
# **Tidiness issue 2:** Merge tweets_df and image_predictions into twitter_archive.<br>
#
# - " Merge the three data frames on one based on the tweet_id data frame"

# %% [markdown]
# #### Code

# %%
#merge twitter_archive_clean with image_predictions_clean in merged_data
merged_data=pd.merge(twitter_archive_clean, image_predictions_clean,on='tweet_id', how='left')

# %%
#merge merged_data with tweets_df_clean
merged_data=pd.merge(merged_data ,tweets_df_clean ,on='tweet_id', how='left')

# %% [markdown]
# #### Test

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2174
# Data columns (total 22 columns):
# tweet_id              2175 non-null int64
# text                  2175 non-null object
# rating_numerator      2175 non-null float64
# rating_denominator    2175 non-null int64
# name                  1391 non-null object
# dogs_stage            344 non-null object
# year                  2175 non-null int64
# month                 2175 non-null int64
# day                   2175 non-null int64
# jpg_url               1994 non-null object
# img_num               1994 non-null float64
# p1                    1994 non-null object
# p1_conf               1994 non-null float64
# p1_dog                1994 non-null object
# p2                    1994 non-null object
# p2_conf               1994 non-null float64
# p2_dog                1994 non-null object
# p3                    1994 non-null object
# p3_conf               1994 non-null float64
# ...

# %% [markdown]
# ### Storing the data

# %%
#store data in csv file
merged_data.to_csv('twitter_archive_master.csv',encoding = 'utf-8')

# %% [markdown]
# # Analyzing and Visualizing Data

# %% [markdown]
# ### What is the percentage of dog stages?

# %%
dog_stages= merged_data.dogs_stage.value_counts()

dog_stages
# Out:
# pupper     234
# doggo       75
# puppo       25
# floofer     10
# Name: dogs_stage, dtype: int64

# %%
labels = 'pupper', 'doggo', 'puppo', 'floofer '
fig = plt.figure(figsize =(9, 9))
plt.title('dog stages percentage')
plt.pie(dog_stages, labels = labels , autopct='%1.1f%%');

# %% [markdown]
# #### Insights

# %% [markdown]
# - pupper is the highest percentage of dogs
# - doggo is the second
# - puppo
# - floofer is the lowest percentage of dogs

# %% [markdown]
# #### Visualizing the most popular dog names

# %%
plt.figure (figsize=(10,8))
names_count=merged_data['name'].value_counts()[0:10].index
color_base=sns.color_palette()[0]
ax=sns.countplot(data=merged_data , y='name' , color= color_base ,order= names_count)
ax.set_title('The Most Common Dog Names')
ax.set(xlabel='dogs count', ylabel='The name of dogs');

# %% [markdown]
# #### insights
# - charlie is the most popular name for dogs then (Tucker, Lucy, penny, oliver, cooper) and then(winston, sadie, lola, bo)

# %% [markdown]
# #### Investigate the relation between retweet count and favorite count

# %%
plt.figure (figsize=(10,8))
plt.scatter(merged_data.retweet_count, merged_data.favorite_count)
plt.title=('The relation between retweet_count and favorite_count')
plt.xlabel('retweet count')
plt.ylabel('favorite count');

# %% [markdown]
# #### insights
# - There's positive relationship between the retweet count and favorite count

# %%
#rating_counts = merged_data.groupby(['rating_numerator']).count()['tweet_id']

# %%
merged_data=merged_data[merged_data['rating_numerator']<=14]

# %%
color=sns.color_palette()[0]
plt.figure(figsize=[15,6])
ax=sns.countplot(data=merged_data , x='rating_numerator', color=color)
ax.set_title('Rating numerators distribution')
ax.set(xlabel='Rating numerators', ylabel='count of ratings(frequancy)')
plt.xticks(rotation=90);

# %% [markdown]
# #### Insights
# - Most tweets are given a rating between 10 to 13.
